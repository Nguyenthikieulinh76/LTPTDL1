# %%
test=(2)
type(test)
# Out:
# int

# %%
test=(1.5)
type(test)
# Out:
# float

# %%
a=(1.5+0.5j)
type(a)
# Out:
# complex

# %%
test=(5<6)
type(test)
# Out:
# bool

# %%
test=('mot','hai','ba')
type(test)
#kieu du liwu bat bien
# Out:
# tuple

# %%
test=('opama')
type(test)
# Out:
# str

# %%
test=['mot','hai','ba']
type(test)
# Out:
# list

# %%
#cau tru
